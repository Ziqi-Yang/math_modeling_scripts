# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv(r"C:\Users\Zarkli\Desktop\math_modeling\math_modeling_scripts\data_process\result\COMPOSED.csv")
plt.figure(figsize=(16,10))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
relation = df.corr()
sns.heatmap(relation,xticklabels=relation.columns,yticklabels=relation.columns,annot=True,cmap=cmap,center=0)
# Out:
# <AxesSubplot:>
